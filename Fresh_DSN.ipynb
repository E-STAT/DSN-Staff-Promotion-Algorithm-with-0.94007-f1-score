# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
redo_train = pd.read_csv('train.csv')
redo_test = pd.read_csv('test.csv')

# %%
redo_train['Age_employed'] = np.log(redo_train.Year_of_recruitment - redo_train.Year_of_birth)
redo_test['Age_employed'] = np.log(redo_test.Year_of_recruitment - redo_test.Year_of_birth)

# %%
redo_train.fillna('unknown', inplace = True)
redo_test.fillna('unknown', inplace = True)

# %%
redo_train.drop(['EmployeeNo', 'Year_of_birth', 'Year_of_recruitment', 'State_Of_Origin'], axis = 1, inplace = True)
redo_test.drop(['EmployeeNo', 'Year_of_birth', 'Year_of_recruitment', 'State_Of_Origin'], axis = 1, inplace = True)

# %%
indx = redo_train[(redo_train['Division']=='Regulatory and Legal services') &  (redo_train['Qualification']=='unknown')].index
redo_train.loc[indx, 'Qualification'] = 'First Degree or HND'

redo_train.loc[indx, 'Qualification'] = 'First Degree or HND'

indx = redo_train[(redo_train['Division']=='Business Finance Operations') &  (redo_train['Qualification']=='unknown')].index
redo_train.loc[indx, 'Qualification'] = 'First Degree or HND'

redo_train.loc[indx, 'Qualification'] = 'First Degree or HND'

indx = redo_train[(redo_train['Division']=='Commercial Sales and Marketing') &  (redo_train['Qualification']=='unknown')].index
redo_train.loc[indx, 'Qualification'] = 'First Degree or HND'

redo_train.loc[indx, 'Qualification'] = 'First Degree or HND'

indx = redo_train[(redo_train['Division']=='Customer Support and Field Operations') &  (redo_train['Qualification']=='unknown')].index
redo_train.loc[indx, 'Qualification'] = 'Non-University Education'

redo_train.loc[indx, 'Qualification'] = 'Non-University Education'

indx = redo_train[(redo_train['Division']=='Information Technology and Solution Support') &  (redo_train['Qualification']=='unknown')].index
redo_train.loc[indx, 'Qualification'] = 'First Degree or HND'

redo_train.loc[indx, 'Qualification'] = 'First Degree or HND'


indx = redo_train[(redo_train['Division']=='Information and Strategy') &  (redo_train['Qualification']=='unknown')].index
redo_train.loc[indx, 'Qualification'] = 'MSc, MBA and PhD'

redo_train.loc[indx, 'Qualification'] = 'MSc, MBA and PhD'


indx = redo_train[(redo_train['Division']=='People/HR Management') &  (redo_train['Qualification']=='unknown')].index
redo_train.loc[indx, 'Qualification'] = 'Non-University Education'

redo_train.loc[indx, 'Qualification'] = 'Non-University Education'


indx = redo_train[(redo_train['Division']=='Research and Innovation') &  (redo_train['Qualification']=='unknown')].index
redo_train.loc[indx, 'Qualification'] = 'MSc, MBA and PhD'

redo_train.loc[indx, 'Qualification'] = 'MSc, MBA and PhD'

indx = redo_train[(redo_train['Division']=='Sourcing and Purchasing') &  (redo_train['Qualification']=='unknown')].index
redo_train.loc[indx, 'Qualification'] = 'First Degree or HND'

redo_train.loc[indx, 'Qualification'] = 'First Degree or HND'

# %%
indx = redo_test[(redo_test['Division']=='Regulatory and Legal services') &  (redo_test['Qualification']=='unknown')].index
redo_test.loc[indx, 'Qualification'] = 'First Degree or HND'

redo_test.loc[indx, 'Qualification'] = 'First Degree or HND'

indx = redo_test[(redo_test['Division']=='Business Finance Operations') &  (redo_test['Qualification']=='unknown')].index
redo_test.loc[indx, 'Qualification'] = 'First Degree or HND'

redo_test.loc[indx, 'Qualification'] = 'First Degree or HND'

indx = redo_test[(redo_test['Division']=='Commercial Sales and Marketing') &  (redo_test['Qualification']=='unknown')].index
redo_test.loc[indx, 'Qualification'] = 'First Degree or HND'

redo_test.loc[indx, 'Qualification'] = 'First Degree or HND'

indx = redo_test[(redo_test['Division']=='Customer Support and Field Operations') &  (redo_test['Qualification']=='unknown')].index
redo_test.loc[indx, 'Qualification'] = 'Non-University Education'

redo_test.loc[indx, 'Qualification'] = 'Non-University Education'

indx = redo_test[(redo_test['Division']=='Information Technology and Solution Support') &  (redo_test['Qualification']=='unknown')].index
redo_test.loc[indx, 'Qualification'] = 'First Degree or HND'

redo_test.loc[indx, 'Qualification'] = 'First Degree or HND'


indx = redo_test[(redo_test['Division']=='Information and Strategy') &  (redo_test['Qualification']=='unknown')].index
redo_test.loc[indx, 'Qualification'] = 'MSc, MBA and PhD'

redo_test.loc[indx, 'Qualification'] = 'MSc, MBA and PhD'


indx = redo_test[(redo_test['Division']=='People/HR Management') &  (redo_test['Qualification']=='unknown')].index
redo_test.loc[indx, 'Qualification'] = 'Non-University Education'

redo_test.loc[indx, 'Qualification'] = 'Non-University Education'


indx = redo_test[(redo_test['Division']=='Research and Innovation') &  (redo_test['Qualification']=='unknown')].index
redo_test.loc[indx, 'Qualification'] = 'MSc, MBA and PhD'

redo_test.loc[indx, 'Qualification'] = 'MSc, MBA and PhD'

indx = redo_test[(redo_test['Division']=='Sourcing and Purchasing') &  (redo_test['Qualification']=='unknown')].index
redo_test.loc[indx, 'Qualification'] = 'First Degree or HND'

redo_test.loc[indx, 'Qualification'] = 'First Degree or HND'

# %%
mymap = {'More than 5': x for x in range(int(6))}
redo_train = redo_train.applymap(lambda s: mymap.get(s) if s in mymap else s)
redo_test = redo_test.applymap(lambda s: mymap.get(s) if s in mymap else s)

# %%
redo_train.head()
# Out:
#                                 Division        Qualification  Gender  \
# 0         Commercial Sales and Marketing     MSc, MBA and PhD  Female
# 1  Customer Support and Field Operations  First Degree or HND    Male
# 2         Commercial Sales and Marketing  First Degree or HND    Male
# 3         Commercial Sales and Marketing  First Degree or HND    Male
# 4               Information and Strategy  First Degree or HND    Male
#
#     Channel_of_Recruitment  Trainings_Attended  Last_performance_score  \
# 0  Direct Internal process                   2                    12.5
# 1        Agency and others                   2                    12.5
# 2  Direct Internal process                   2                     7.5
# 3        Agency and others                   3                     2.5
# 4  Direct Internal process                   3                     7.5
#
#    Targets_met  Previous_Award  Training_score_average Foreign_schooled  \
# ...

# %%
from xklearn.preprocessing import CountEncoder

# %%
redo_train['Division_Qualification'] = redo_train['Division'] + '_' + redo_train['Qualification']
redo_test['Division_Qualification'] = redo_test['Division'] + '_' + redo_test['Qualification']

redo_train.head()
# Out:
#                                 Division        Qualification  Gender  \
# 0         Commercial Sales and Marketing     MSc, MBA and PhD  Female
# 1  Customer Support and Field Operations  First Degree or HND    Male
# 2         Commercial Sales and Marketing  First Degree or HND    Male
# 3         Commercial Sales and Marketing  First Degree or HND    Male
# 4               Information and Strategy  First Degree or HND    Male
#
#     Channel_of_Recruitment  Trainings_Attended  Last_performance_score  \
# 0  Direct Internal process                   2                    12.5
# 1        Agency and others                   2                    12.5
# 2  Direct Internal process                   2                     7.5
# 3        Agency and others                   3                     2.5
# 4  Direct Internal process                   3                     7.5
#
#    Targets_met  Previous_Award  Training_score_average Foreign_schooled  \
# ...

# %%
redo_train['Division_Qualification_Channel'] = redo_train['Division'] + '_' + redo_train['Qualification'] + '_' + redo_train['Channel_of_Recruitment']

redo_test['Division_Qualification_Channel'] = redo_test['Division'] + '_' + redo_test['Qualification'] + '_' + redo_test['Channel_of_Recruitment']

# %%
redo_train['Foreign_schooled_Marital'] = redo_train['Foreign_schooled'] + '_' + redo_train['Marital_Status']

redo_test['Foreign_schooled_Marital'] = redo_test['Foreign_schooled'] + '_' + redo_test['Marital_Status']

# %%
redo_train['Past_Previous_disp'] = redo_train['Past_Disciplinary_Action'] + '_' + redo_train['Previous_IntraDepartmental_Movement']

redo_test['Past_Previous_disp'] = redo_test['Past_Disciplinary_Action'] + '_' + redo_test['Previous_IntraDepartmental_Movement']

# %%
redo_train.shape
# Out:
# (38312, 20)

# %%
redo_train.columns
# Out:
# Index(['Division', 'Qualification', 'Gender', 'Channel_of_Recruitment',
#        'Trainings_Attended', 'Last_performance_score', 'Targets_met',
#        'Previous_Award', 'Training_score_average', 'Foreign_schooled',
#        'Marital_Status', 'Past_Disciplinary_Action',
#        'Previous_IntraDepartmental_Movement', 'No_of_previous_employers',
#        'Promoted_or_Not', 'Age_employed', 'Division_Qualification',
#        'Division_Qualification_Channel', 'Foreign_schooled_Marital',
#        'Past_Previous_disp'],
#       dtype='object')

# %%
redo_test.columns
# Out:
# Index(['Division', 'Qualification', 'Gender', 'Channel_of_Recruitment',
#        'Trainings_Attended', 'Last_performance_score', 'Targets_met',
#        'Previous_Award', 'Training_score_average', 'Foreign_schooled',
#        'Marital_Status', 'Past_Disciplinary_Action',
#        'Previous_IntraDepartmental_Movement', 'No_of_previous_employers',
#        'Age_employed', 'Division_Qualification',
#        'Division_Qualification_Channel', 'Foreign_schooled_Marital',
#        'Past_Previous_disp'],
#       dtype='object')

# %%
redo_test.shape
# Out:
# (16496, 19)

# %%
from sklearn.preprocessing import LabelEncoder
#LabelEncoder?

# %%
cat_features = (['Division', 'Qualification', 'Division_Qualification','Gender', 'Channel_of_Recruitment', 'Foreign_schooled', 'Marital_Status', 'Past_Disciplinary_Action', 
                'Previous_IntraDepartmental_Movement', 'Division_Qualification_Channel', 'Foreign_schooled_Marital', 'Past_Previous_disp'])

# %%
encoder = LabelEncoder()
encoded = redo_train[cat_features].apply(encoder.fit_transform)
encoded_test = redo_test[cat_features].apply(encoder.fit_transform)

# %%
redo_train.drop(['Division', 'Qualification', 'Gender','Division_Qualification', 'Channel_of_Recruitment', 'Foreign_schooled', 'Marital_Status', 'Past_Disciplinary_Action', 
                'Previous_IntraDepartmental_Movement', 'Division_Qualification_Channel', 'Foreign_schooled_Marital', 'Past_Previous_disp'], axis = 1, inplace = True)

redo_test.drop(['Division', 'Qualification', 'Gender', 'Division_Qualification','Channel_of_Recruitment', 'Foreign_schooled', 'Marital_Status', 'Past_Disciplinary_Action', 
                'Previous_IntraDepartmental_Movement', 'Division_Qualification_Channel', 'Foreign_schooled_Marital', 'Past_Previous_disp'], axis = 1, inplace = True)

# %%
redo_train= redo_train.join(encoded)
#print(redo_train.shape)

redo_test= redo_test.join(encoded_test)
#redo_test.shape

# %%
redo_test.head()
# Out:
#    Trainings_Attended  Last_performance_score  Targets_met  Previous_Award  \
# 0                   2                     7.5            0               0
# 1                   2                     0.0            0               0
# 2                   2                     7.5            0               0
# 3                   2                     2.5            0               0
# 4                   2                     7.5            1               0
#
#    Training_score_average No_of_previous_employers  Age_employed  Division  \
# 0                      65                        1      3.713572         3
# 1                      69                        1      3.295837         3
# 2                      76                        1      3.332205         7
# 3                      52                        1      3.218876         2
# 4                      69                        0      3.433987         3
#
# ...

# %%
No_of_previous_employers_ = pd.to_numeric(redo_train.No_of_previous_employers)
No_of_previous_employers__ = pd.to_numeric(redo_test.No_of_previous_employers)

redo_train.drop(['No_of_previous_employers'], axis = 1, inplace = True)
redo_test.drop(['No_of_previous_employers'], axis = 1, inplace = True)

redo_train = pd.concat([redo_train, No_of_previous_employers_], axis = 1)
redo_test = pd.concat([redo_test, No_of_previous_employers__], axis = 1)

# %%
redo_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38312 entries, 0 to 38311
# Data columns (total 20 columns):
# Trainings_Attended                     38312 non-null int64
# Last_performance_score                 38312 non-null float64
# Targets_met                            38312 non-null int64
# Previous_Award                         38312 non-null int64
# Training_score_average                 38312 non-null int64
# Promoted_or_Not                        38312 non-null int64
# Age_employed                           38312 non-null float64
# Division                               38312 non-null int64
# Qualification                          38312 non-null int64
# Division_Qualification                 38312 non-null int64
# Gender                                 38312 non-null int64
# Channel_of_Recruitment                 38312 non-null int64
# Foreign_schooled                       38312 non-null int64
# Marital_Status                         38312 non-null int64
# ...

# %%
y = redo_train['Promoted_or_Not']
X = redo_train.drop(['Promoted_or_Not'], axis=1)

# %%
import lightgbm as lgb
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import auc, accuracy_score, roc_auc_score, roc_curve, f1_score
from sklearn.model_selection import GridSearchCV

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=0)
X_train.columns
# Out:
# Index(['Trainings_Attended', 'Last_performance_score', 'Targets_met',
#        'Previous_Award', 'Training_score_average', 'Age_employed', 'Division',
#        'Qualification', 'Division_Qualification', 'Gender',
#        'Channel_of_Recruitment', 'Foreign_schooled', 'Marital_Status',
#        'Past_Disciplinary_Action', 'Previous_IntraDepartmental_Movement',
#        'Division_Qualification_Channel', 'Foreign_schooled_Marital',
#        'Past_Previous_disp', 'No_of_previous_employers'],
#       dtype='object')

# %%
estimator = lgb.LGBMClassifier(learning_rate = 0.15, metric = 'l1', 
                        n_estimators = 24, num_leaves = 38)


param_grid = {
    'n_estimators': [x for x in range(24,40,2)],
    'learning_rate': [0.10, 0.125, 0.15, 0.175, 0.2]}
gridsearch = GridSearchCV(estimator, param_grid)

gridsearch.fit(X_train, y_train,
        eval_set = [(X_test, y_test)],
        eval_metric = ['auc', 'binary_logloss'],
        early_stopping_rounds = 5,
              verbose = 1)
# Out:
# [1]	valid_0's binary_logloss: 0.259233	valid_0's auc: 0.851248	valid_0's l1: 0.149083
# Training until validation scores don't improve for 5 rounds.
# [2]	valid_0's binary_logloss: 0.245946	valid_0's auc: 0.858911	valid_0's l1: 0.145017
# [3]	valid_0's binary_logloss: 0.232676	valid_0's auc: 0.876497	valid_0's l1: 0.140714
# [4]	valid_0's binary_logloss: 0.224438	valid_0's auc: 0.875491	valid_0's l1: 0.137122
# [5]	valid_0's binary_logloss: 0.217714	valid_0's auc: 0.876805	valid_0's l1: 0.133896
# [6]	valid_0's binary_logloss: 0.210995	valid_0's auc: 0.884355	valid_0's l1: 0.130652
# [7]	valid_0's binary_logloss: 0.205516	valid_0's auc: 0.885198	valid_0's l1: 0.127715
# [8]	valid_0's binary_logloss: 0.200751	valid_0's auc: 0.887698	valid_0's l1: 0.125058
# [9]	valid_0's binary_logloss: 0.19675	valid_0's auc: 0.887951	valid_0's l1: 0.122583
# [10]	valid_0's binary_logloss: 0.193518	valid_0's auc: 0.887747	valid_0's l1: 0.120467
# ...

# %%
print('Best parameters found by grid search are:', gridsearch.best_params_)
# Out:
# Best parameters found by grid search are: {'learning_rate': 0.175, 'n_estimators': 26}

# %%
gbm = lgb.LGBMClassifier(learning_rate = 0.175, metric = 'l1', 
                        n_estimators = 26)


gbm.fit(X_train, y_train,
        eval_set=[(X_test, y_test)],
        eval_metric=['auc', 'binary_logloss'],
early_stopping_rounds=5)
# Out:
# [1]	valid_0's binary_logloss: 0.241582	valid_0's auc: 0.845012	valid_0's l1: 0.143713
# Training until validation scores don't improve for 5 rounds.
# [2]	valid_0's binary_logloss: 0.222386	valid_0's auc: 0.870169	valid_0's l1: 0.136506
# [3]	valid_0's binary_logloss: 0.208898	valid_0's auc: 0.889475	valid_0's l1: 0.130691
# [4]	valid_0's binary_logloss: 0.20047	valid_0's auc: 0.889026	valid_0's l1: 0.125895
# [5]	valid_0's binary_logloss: 0.193773	valid_0's auc: 0.888983	valid_0's l1: 0.121543
# [6]	valid_0's binary_logloss: 0.189271	valid_0's auc: 0.888374	valid_0's l1: 0.118434
# [7]	valid_0's binary_logloss: 0.184723	valid_0's auc: 0.891049	valid_0's l1: 0.115548
# [8]	valid_0's binary_logloss: 0.181709	valid_0's auc: 0.891753	valid_0's l1: 0.113294
# [9]	valid_0's binary_logloss: 0.178963	valid_0's auc: 0.892501	valid_0's l1: 0.111064
# [10]	valid_0's binary_logloss: 0.177089	valid_0's auc: 0.892555	valid_0's l1: 0.109373
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=0)
X_train.columns
# Out:
# Index(['Trainings_Attended', 'Last_performance_score', 'Targets_met',
#        'Previous_Award', 'Training_score_average', 'Age_employed', 'Division',
#        'Qualification', 'Division_Qualification', 'Gender',
#        'Channel_of_Recruitment', 'Foreign_schooled', 'Marital_Status',
#        'Past_Disciplinary_Action', 'Previous_IntraDepartmental_Movement',
#        'Division_Qualification_Channel', 'Foreign_schooled_Marital',
#        'Past_Previous_disp', 'No_of_previous_employers'],
#       dtype='object')

# %%
y_pred = gbm.predict(redo_test)
y_predict = y_pred.astype('int64')
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
dsn_test_s = pd.read_csv('test.csv')
dsn_test_s.head()
# Out:
#     EmployeeNo                                     Division  \
# 0  YAK/S/00005  Information Technology and Solution Support
# 1  YAK/S/00011  Information Technology and Solution Support
# 2  YAK/S/00015                      Research and Innovation
# 3  YAK/S/00016        Customer Support and Field Operations
# 4  YAK/S/00017  Information Technology and Solution Support
#
#          Qualification Gender   Channel_of_Recruitment  Trainings_Attended  \
# 0  First Degree or HND   Male        Agency and others                   2
# 1                  NaN   Male  Direct Internal process                   2
# 2     MSc, MBA and PhD   Male  Direct Internal process                   2
# 3  First Degree or HND   Male        Agency and others                   2
# 4  First Degree or HND   Male        Agency and others                   2
#
#    Year_of_birth  Last_performance_score  Year_of_recruitment  Targets_met  \
# ...

# %%
submission = pd.DataFrame({'EmployeeNo':dsn_test_s['EmployeeNo'], 'Promoted_or_Not': y_predict})
submission
# Out:
#         EmployeeNo  Promoted_or_Not
# 0      YAK/S/00005                0
# 1      YAK/S/00011                0
# 2      YAK/S/00015                0
# 3      YAK/S/00016                0
# 4      YAK/S/00017                0
# ...            ...              ...
# 16491  YAK/S/54797                1
# 16492  YAK/S/54798                0
# 16493  YAK/S/54800                0
# 16494  YAK/S/54803                0
# 16495  YAK/S/54804                0
#
# [16496 rows x 2 columns]

# %%
filename = 'gbm_new.csv'
submission.to_csv(filename,index = False)
print('saved file:' + filename)
# Out:
# saved file:gbm_new2.csv
